# %%
import pandas as pd
import os
import csv
import numpy as np
from scipy import stats
from matplotlib import pyplot as plt
# %matplotlib
import matplotlib.lines as mlines
import matplotlib.pyplot as plt
# Out:
# Using matplotlib backend: Qt5Agg

# %%
from Experimentos2 import Experimentos, labelLines
# Out:
# [Errno 2] No such file or directory: '.\\Data\\5cc50C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc50C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc50C - max av cup.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc50C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc54C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc54C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc54C - max av cup.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc54C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\25cc54C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\25cc54C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\25cc54C - max av cup.csv'
# [Errno 2] No such file or directory: '.\\Data\\25cc54C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc60C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc60C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc60C - max av cup.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc60C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\25cc60C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\25cc60C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\25cc60C - max av cup.csv'
# [Errno 2] No such file or directory: '.\\Data\\25cc60C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc59C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc59C - max av cup.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc59C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc47C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc47C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc47C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc55C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc55C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc55C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\25cc58C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\25cc58C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\25cc58C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\25cc70C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\25cc70C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\25cc70C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc67C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc67C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc67C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc59C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc59C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc59C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc63C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc63C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc63C - max av cup.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc63C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc59C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc59C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc59C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc49C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc49C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc49C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\25cc62C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\25cc62C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\25cc62C - max av cup.csv'
# [Errno 2] No such file or directory: '.\\Data\\25cc62C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc62C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc62C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc62C - max av cup.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc62C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc53C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc53C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc53C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\5a25cc56C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\5a25cc56C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\5a25cc56C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc57C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc57C - max av cup.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc57C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\25cc50C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\25cc50C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\25cc50C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc55C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc55C - max av cup.csv'
# 'frente'
# [Errno 2] No such file or directory: '.\\Data\\1cc24C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc24C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc24C - max av cup.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc24C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc57C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc57C - max av cup.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc57C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc24C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc24C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc24C - max av cup.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc24C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc55C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc55C - max av cup.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc55C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc58C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc58C - max av cup.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc58C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc48C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc48C - max av cup.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc48C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc51C - fspot.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc51C - max av cup.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc51C - frente.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc48C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\5cc48C - max av cup.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc50C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\10cc50C - max av cup.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc54,7C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc54,7C - max av cup.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc52C - max av.csv'
# [Errno 2] No such file or directory: '.\\Data\\1cc52C - max av cup.csv'

# %%
for i, exp in enumerate(Experimentos):
   print(i, exp, (exp.temp is not None))
# Out:
# 0 5cc50C.csv False
# 1 1cc54C.csv False
# 2 25cc54C.csv False
# 3 10cc60C.csv False
# 4 25cc60C.csv False
# 5 1cc59C.csv True
# 6 1cc47C.csv False
# 7 1cc55C.csv False
# 8 25cc58C.csv False
# 9 25cc70C.csv False
# 10 10cc67C.csv False
# 11 10cc59C.csv False
# 12 5cc63C.csv False
# 13 5cc59C.csv False
# 14 10cc49C.csv False
# 15 25cc62C.csv False
# 16 1cc62C.csv False
# 17 5cc53C.csv False
# 18 5a25cc56C.csv False
# 19 5cc57C.csv True
# 20 25cc50C.csv False
# 21 10cc55C.csv True
# 22 1cc24C.csv False
# 23 10cc57C.csv True
# 24 10cc24C.csv False
# 25 5cc55C.csv True
# 26 5cc58C.csv True
# 27 1cc48C.csv True
# 28 1cc51C.csv True
# 29 5cc48C.csv False
# 30 10cc50C.csv False
# 31 1cc54,7C.csv False
# 32 1cc52C.csv False

# %%
Experimentos[19].temp.describe()
# Out:
#                 tf           av          max  moving average   moving std
# count  1942.000000  1942.000000  1942.000000     1942.000000  1942.000000
# mean   1014.517236    43.750463    45.956282       45.958419     0.362743
# std     593.441268     5.530277     4.719547        4.720493     1.205897
# min       1.000000    34.400000    40.000000       40.300000     0.022361
# 25%     497.349000    39.400000    42.100000       42.100000     0.048936
# 50%    1006.465000    42.500000    44.600000       44.600000     0.059824
# 75%    1524.915000    46.500000    48.300000       48.337500     0.101433
# max    2058.664000    55.800000    57.300000       56.850000     7.420305

# %%
Experimentos[6].tempcup.columns
# Out:
# Index(['tf', 'av', 'max', 'tc', 'cp', 'moving average', 'moving std'], dtype='object')

# %%
pd.set_option("display.max_columns",22)
Experimentos[6].param.head()
# Out:
#    densidad manjar  modelo 3D  volumen total teorico  t amb  \
# 0             1240        NaN                0.00143   23.9
#
#            termocupla    caudal  angulo inclinacion  NOMBRE  Obs  Exp #  \
# 0  si, punto eyeccion  0.000001                  10  1cc47C  NaN      7
#
#    uso manjar  t max            fecha  min  max  framei  framef  \
# 0           2   46.7  26/06/2016 0:00   28   52      63    1800
#
#    result: largo final  result: largo total  result: ancho max final  \
# 0                 0.29                0.338                     0.27
#
#    result: espesor max final  result: distancia espesor final
# 0                      0.021                             0.25

# %%
Experimentos[29].temp4cup.describe()
# Out:
#                 tf          sp1          sp2          sp3          sp4  \
# count  3914.000000  3914.000000  3914.000000  3914.000000  3914.000000
# mean   2080.124211    34.236510    34.207767    33.671410    26.524732
# std    1218.754649     4.855213     4.001802     3.865733     1.484726
# min       2.000000    28.500000    24.000000    23.900000    23.800000
# 25%    1017.582000    30.500000    31.400000    31.300000    25.800000
# 50%    2067.665000    33.100000    33.300000    33.200000    26.700000
# 75%    3126.047000    36.600000    36.000000    35.800000    27.600000
# max    4214.796000    49.400000    46.200000    43.000000    29.200000
#
#                 tc          cp1          cp2          cp3          cp4  \
# count  3914.000000  3914.000000  3914.000000  3914.000000  3914.000000
# mean   2065.953756    35.841594    35.672892    35.184262    31.987404
# std    1212.755400     3.460682     2.731401     2.891054     1.673267
# min       2.000000    30.300000    25.800000    25.700000    26.100000
# 25%    1009.250000    32.900000    33.500000    33.000000    30.800000
# 50%    2052.500000    35.600000    36.000000    35.400000    31.900000
# 75%    3106.750000    39.075000    38.300000    38.000000    33.200000
# max    4194.000000    41.700000    39.800000    39.500000    35.000000
#
#        moving average   moving std
# count     3914.000000  3914.000000
# mean        34.240687     0.207511
# std          4.860622     0.682627
# min         28.500000     0.000000
# 25%         30.500000     0.048936
# 50%         33.100000     0.058714
# 75%         36.637500     0.075394
# max         49.050000     7.063492

# %%
velos.head()
# Out:
#     nombre        v1        v2        t*     L*
# 0   5cc50C  0.001293  0.000081   342.733  0.450
# 1   1cc54C  0.000260  0.000000  1708.967  0.417
# 2  25cc54C  0.004453  0.000058    78.967  0.350
# 3  10cc60C  0.002862  0.000211   152.867  0.432
# 4  25cc60C  0.004898  0.000038    88.233  0.379

# %%
#for i in range(33):
#    print(velos.iloc[i,:]['nombre'])

# %%
velos.iloc[i,:]
# Out:
# nombre       1cc52C
# v1        0.0001637
# v2            2e-06
# t*          1744.47
# L*            0.275
# Name: 32, dtype: object

# %%
Experimentos[32].param.head()
# Out:
#    densidad manjar  modelo 3D  volumen total teorico  t amb    termocupla  \
# 0             1240  hay fotos                0.00143     22  si, 4 puntos
#
#      caudal  angulo inclinacion  NOMBRE                                  Obs  \
# 0  0.000001                10.2  1cc52C  manjar muy viscoso paquete guardado
#
#    Exp #               ...                           fecha  min   max  framei  \
# 0     33               ...                 04-10-2016 0:00   24  54.4      24
#
#    framef  result: largo final  result: largo total  result: ancho max final  \
# 0    3500                0.218                0.293                    0.245
#
#    result: espesor max final  result: distancia espesor final
# 0                      0.028                              0.1
#
# [1 rows x 22 columns]

# %%
Experimentos[32].temp4cup.tail()
# Out:
#             tf   sp1   sp2   sp3   sp4    tc   cp1   cp2   cp3   cp4  \
# 5708  5730.661  30.2  29.9  22.1  21.2  5708  29.8  34.8  21.9  25.1
# 5709  5731.661  30.2  29.9  22.1  21.2  5709  29.7  34.9  21.9  25.1
# 5710  5732.661  30.2  29.9  22.1  21.3  5710  29.7  34.8  21.9  25.2
# 5711  5733.661  30.2  29.9  22.1  21.2  5711  29.8  34.8  21.9  25.2
# 5712  5734.661  30.2  29.9  22.1  21.2  5712  29.7  34.8  21.9  25.1
#
#       moving average  moving std
# 5708            30.2    0.044721
# 5709            30.2    0.044721
# 5710            30.2    0.044721
# 5711            30.2    0.044721
# 5712            30.2    0.044721

# %%
#CORRER
velos = pd.read_excel('Velocidades y punto.xlsx')

# %%
#CORRER
for exp in Experimentos:
    exp.param['tiempo fin eyeccion'] = exp.param['volumen total teorico']/exp.param['caudal']

# %%
listatempcup = []

for exp in Experimentos:
    if exp.tempcup is not None:
        print(exp.param['NOMBRE'],exp.tempcup.head())
        holder = {} #es un diccionario 
        holder['nombre'] = exp.param['NOMBRE'][0]#solo el valor de la primera fila
        for i in range(33):
            if exp.param['NOMBRE'][0]==velos.iloc[i,:]['nombre']:
                holder['v1'] = velos.iloc[i,:]['v1']
                holder['v2'] = velos.iloc[i,:]['v2']
                holder['L*'] = velos.iloc[i,:]['L*']
                holder['t*'] = velos.iloc[i,:]['t*']
            holder['tf'] = exp.tempcup['tf']#toda la columna
            holder['av'] = exp.tempcup['av']#toda la columna
            holder['max'] = exp.tempcup['max']#toda la columna
            holder['tc'] = exp.tempcup['tc']#toda la columna
            holder['cp'] = exp.tempcup['cp']#toda la columna
            holder['teyec'] = exp.param['tiempo fin eyeccion']

    #holder['largo'] = exp.perfil['perfil: distancia']#toda la columna
        holder['caudal'] = exp.param['caudal'][0]#solo el valor de la primera fila
        holder['angulo'] = exp.param['angulo inclinacion'][0]
    #holder["rango temperatura"] = rango_temperatura(exp.param["t max"][0])
        holder['tamb'] = exp.param['t amb'][0]
    #holder['tmax'] = exp.tempcup['max'].max()

        listatempcup.append(holder)
# Out:
# 0    1cc47C
# Name: NOMBRE, dtype: object     tf    av   max   tc    cp  moving average  moving std
# 3  3.0  27.5  30.9  3.0  42.5           50.45    10.14652
# 4  4.0  28.0  31.6  4.0  44.6           50.45    10.14652
# 5  5.0  28.4  31.6  5.0  45.1           50.45    10.14652
# 6  6.0  28.7  31.8  6.0  45.5           50.45    10.14652
# 7  7.0  36.2  48.2  7.0  46.2           50.45    10.14652
# 0    1cc55C
# Name: NOMBRE, dtype: object     tf    av   max  tc    cp  moving average  moving std
# 1  1.0  27.4  45.7   1  26.5            51.6    5.549535
# 2  2.0  35.8  48.8   2  38.2            51.6    5.549535
# 3  3.0  41.7  49.9   3  48.1            51.6    5.549535
# 4  4.0  45.5  49.3   4  51.5            51.6    5.549535
# 5  5.0  48.0  50.8   5  52.4            51.6    5.549535
# 0    25cc58C
# Name: NOMBRE, dtype: object     tf    av   max  tc    cp  moving average  moving std
# 2  2.0  53.9  60.4   2  45.9           61.85    9.669328
# 3  3.0  57.2  59.1   3  44.3           61.85    9.669328
# 4  4.0  61.0  61.7   4  46.0           61.85    9.669328
# 5  5.0  62.4  62.7   5  48.2           61.85    9.669328
# 6  6.0  62.1  62.6   6  48.8           61.85    9.669328
# 0    25cc70C
# Name: NOMBRE, dtype: object     tf    av   max  tc     cp  moving average  moving std
# 2  2.0  54.2  56.4   2  37.78           63.35    9.518452
# 3  3.0  60.2  60.5   3  61.03           63.35    9.518452
# 4  4.0  59.8  60.7   4  62.69           63.35    9.518452
# 5  5.0  61.6  61.9   5  64.39           63.35    9.518452
# 6  6.0  60.5  61.8   6  63.08           63.35    9.518452
# 0    10cc67C
# Name: NOMBRE, dtype: object       tf    av   max  tc    cp  moving average  moving std
# 1  1.066  48.7  73.3   1  24.3            62.7    6.743361
# 2  2.133  58.0  60.7   2  53.5            62.7    6.743361
# 3  3.200  59.2  61.5   3  62.3            62.7    6.743361
# 4  4.266  61.0  61.6   4  64.2            62.7    6.743361
# 5  5.333  61.0  61.7   5  64.5            62.7    6.743361
# 0    10cc59C
# Name: NOMBRE, dtype: object       tf    av   max  tc    cp  moving average  moving std
# 1  1.067  37.3  52.8   1  28.1           56.05    6.656307
# 2  2.133  35.4  52.9   2  43.0           56.05    6.656307
# 3  3.200  35.0  53.6   3  52.7           56.05    6.656307
# 4  4.267  50.3  55.3   4  56.7           56.05    6.656307
# 5  5.333  55.0  56.4   5  58.3           56.05    6.656307
# 0    5cc59C
# Name: NOMBRE, dtype: object       tf    av   max   tc    cp  moving average  moving std
# 3  3.033  43.8  54.6  3.0  44.0            56.6    4.023546
# 4  4.033  51.1  55.4  4.0  49.8            56.6    4.023546
# 5  5.033  54.9  55.9  5.0  52.6            56.6    4.023546
# 6  6.033  55.4  56.0  6.0  53.9            56.6    4.023546
# 7  7.033  55.0  56.0  7.0  55.0            56.6    4.023546
# 0    10cc49C
# Name: NOMBRE, dtype: object     tf    av   max  tc    cp  moving average  moving std
# 2  2.0  41.0  43.8   2  36.0            46.5    2.811536
# 3  3.0  44.5  45.7   3  41.3            46.5    2.811536
# 4  4.0  46.2  46.7   4  44.5            46.5    2.811536
# 5  5.0  46.4  46.8   5  45.7            46.5    2.811536
# 6  6.0  46.5  46.9   6  46.1            46.5    2.811536
# 0    5cc53C
# Name: NOMBRE, dtype: object     tf    av   max  tc    cp  moving average  moving std
# 0  0.0  29.6  35.0   0  26.9            35.1    8.017835
# 1  1.0  37.4  35.1   1  27.3            35.1    8.017835
# 2  2.0  44.1  35.2   2  40.2            35.1    8.017835
# 3  3.0  47.5  35.1   3  42.5            35.1    8.017835
# 4  4.0  48.6  34.9   4  46.3            35.1    8.017835
# 0    5a25cc56C
# Name: NOMBRE, dtype: object     tf    av   max  tc    cp  moving average  moving std
# 2  2.0  34.4  48.8   2  27.4            52.8    6.680724
# 3  3.0  47.7  51.6   3  27.7            52.8    6.680724
# 4  4.0  50.3  52.0   4  28.3            52.8    6.680724
# 5  5.0  50.7  52.3   5  38.2            52.8    6.680724
# 6  6.0  51.2  52.6   6  47.6            52.8    6.680724
# 0    25cc50C
# Name: NOMBRE, dtype: object     tf    av   max  tc    cp  moving average  moving std
# 1  1.0  45.5  48.4   1  37.9           47.65    2.309112
# 2  2.0  47.4  48.5   2  47.0           47.65    2.309112
# 3  3.0  46.4  48.1   3  46.8           47.65    2.309112
# 4  4.0  45.9  48.0   4  46.5           47.65    2.309112
# 5  5.0  45.7  47.9   5  46.3           47.65    2.309112

# %%
listatemp4cup = []

for exp in Experimentos:
    if exp.temp4cup is not None:
        print(exp.param['NOMBRE'],exp.temp4cup.head())
        holder = {} #es un diccionario 
        holder['nombre'] = exp.param['NOMBRE'][0]#solo el valor de la primera fila
        for i in range(33):
            if exp.param['NOMBRE'][0]==velos.iloc[i,:]['nombre']:
                holder['v1'] = velos.iloc[i,:]['v1']
                holder['v2'] = velos.iloc[i,:]['v2']
                holder['L*'] = velos.iloc[i,:]['L*']
                holder['t*'] = velos.iloc[i,:]['t*']
            holder['tf'] = exp.temp4cup['tf']#toda la columna
            holder['av'] = exp.temp4cup['sp1']#toda la columna
            holder['sp2'] = exp.temp4cup['sp2']#toda la columna
            holder['sp3'] = exp.temp4cup['sp3']#toda la columna
            holder['sp4'] = exp.temp4cup['sp4']#toda la columna
            holder['cp1'] = exp.temp4cup['cp1']#toda la columna
            holder['cp2'] = exp.temp4cup['cp2']#toda la columna
            holder['cp3'] = exp.temp4cup['cp3']#toda la columna
            holder['cp4'] = exp.temp4cup['cp4']#toda la columna
            holder['tc'] = exp.temp4cup['tc']#toda la columna
            holder['frente'] = exp.frente['frente']
            holder['frame'] = exp.frente['frame']
            holder['avance'] = exp.dinamica['avance: largo total flujo']
            holder['ancho'] = exp.dinamica['avance: ancho maximo']
            holder['tiempo'] = exp.dinamica['avance: tiempo']            
            holder['teyec'] = exp.param['tiempo fin eyeccion']


    #holder['largo'] = exp.perfil['perfil: distancia']#toda la columna
        holder['caudal'] = exp.param['caudal'][0]#solo el valor de la primera fila
        holder['angulo'] = exp.param['angulo inclinacion'][0]
    #holder["rango temperatura"] = rango_temperatura(exp.param["t max"][0])
        holder['tamb'] = exp.param['t amb'][0]
    #holder['tmax'] = exp.tempcup['max'].max()

        listatemp4cup.append(holder)
# Out:
# 0    5cc48C
# Name: NOMBRE, dtype: object     tf   sp1   sp2   sp3   sp4  tc   cp1   cp2   cp3   cp4  moving average  \
# 2  2.0  40.9  24.0  24.0  23.9   2  32.0  25.8  25.7  26.1           46.75
# 3  3.0  46.7  24.1  24.0  23.9   3  35.0  26.3  26.1  26.9           46.75
# 4  4.0  46.8  24.0  23.9  23.9   4  35.6  26.6  26.4  27.1           46.75
# 5  5.0  45.7  24.1  24.0  23.9   5  35.9  26.6  26.5  27.2           46.75
# 6  6.0  45.7  24.1  24.0  23.9   6  36.2  26.8  26.5  27.2           46.75
#
#    moving std
# 2    7.063492
# 3    7.063492
# 4    7.063492
# 5    7.063492
# 6    7.063492
# 0    10cc50C
# Name: NOMBRE, dtype: object     tf   sp4   sp3   sp2   sp1  tc   cp1   cp2   cp3   cp4  moving average  \
# 2  2.0  24.9  25.0  25.0  46.6   2  38.6  27.4  27.3  27.8            49.2
# 3  3.0  24.9  25.0  25.1  44.6   3  39.0  27.8  27.6  27.9            49.2
# 4  4.0  25.0  25.0  25.2  49.2   4  39.2  27.8  27.7  28.0            49.2
# 5  5.0  25.0  25.1  25.1  50.3   5  39.3  27.9  27.6  28.1            49.2
# 6  6.0  25.0  25.1  25.2  50.5   6  39.4  27.9  27.7  28.1            49.2
#
#    moving std
# 2    5.167192
# 3    5.167192
# 4    5.167192
# 5    5.167192
# 6    5.167192
# 0    1cc54,7C
# Name: NOMBRE, dtype: object     tf   sp1   sp2   sp3   sp4  tc   cp1   cp2   cp3   cp4  moving average  \
# 2  2.0  53.0  23.2  22.6  22.5   2  40.9  27.8  22.7  27.8            53.0
# 3  3.0  53.3  23.2  22.6  22.5   3  42.8  28.4  22.9  28.4            53.0
# 4  4.0  53.7  23.2  22.6  22.6   4  44.0  28.7  22.9  28.9            53.0
# 5  5.0  52.5  23.3  22.7  22.6   5  44.9  28.8  22.9  29.1            53.0
# 6  6.0  52.0  23.3  22.6  22.5   6  45.1  28.9  22.8  29.2            53.0
#
#    moving std
# 2    7.257773
# 3    7.257773
# 4    7.257773
# 5    7.257773
# 6    7.257773
# 0    1cc52C
# Name: NOMBRE, dtype: object     tf   sp1   sp2   sp3   sp4  tc   cp1   cp2   cp3   cp4  moving average  \
# 2  2.0  51.4  21.7  21.7  21.7   2  32.1  21.8  21.3  24.8           51.05
# 3  3.0  50.0  21.7  21.8  21.6   3  38.5  21.8  21.4  28.0           51.05
# 4  4.0  51.2  21.8  21.8  21.7   4  40.9  21.8  21.4  29.0           51.05
# 5  5.0  51.9  21.7  21.8  21.7   5  42.5  21.8  21.4  30.2           51.05
# 6  6.0  51.9  21.7  21.8  21.7   6  44.3  21.9  21.3  30.4           51.05
#
#    moving std
# 2    8.559943
# 3    8.559943
# 4    8.559943
# 5    8.559943
# 6    8.559943

# %%
listatemp = []

for exp in Experimentos:
    if exp.temp is not None:
        print(exp.param['NOMBRE'],exp.temp.head())
        holder = {} #es un diccionario 
        holder['nombre'] = exp.param['NOMBRE'][0]#solo el valor de la primera fila
        for i in range(33):
            if exp.param['NOMBRE'][0]==velos.iloc[i,:]['nombre']:
                holder['v1'] = velos.iloc[i,:]['v1']
                holder['v2'] = velos.iloc[i,:]['v2']
                holder['L*'] = velos.iloc[i,:]['L*']
                holder['t*'] = velos.iloc[i,:]['t*']
            holder['av'] = exp.temp['av']#toda la columna
            holder['max'] = exp.temp['max']#toda la columna
            holder['tf'] = exp.temp['tf']#toda la columna
        holder['caudal'] = exp.param['caudal'][0]#solo el valor de la primera fila
        holder['angulo'] = exp.param['angulo inclinacion'][0]
        holder['tamb'] = exp.param['t amb'][0]
        holder['teyec'] = exp.param['tiempo fin eyeccion']


        listatemp.append(holder)
# Out:
# 0    1cc59C
# Name: NOMBRE, dtype: object     tf    av   max  moving average  moving std
# 0  0.0  32.4  35.0            35.0    1.470938
# 1  1.0  32.4  35.0            35.0    1.470938
# 2  2.0  32.3  35.0            35.0    1.470938
# 3  3.0  32.3  35.0            35.0    1.470938
# 4  4.0  32.3  35.0            35.0    1.470938
# 0    5cc57C
# Name: NOMBRE, dtype: object     tf    av   max  moving average  moving std
# 1  1.0  34.4  55.0           56.85    5.173963
# 2  2.0  51.9  56.5           56.85    5.173963
# 3  3.0  53.2  56.3           56.85    5.173963
# 4  4.0  55.2  57.1           56.85    5.173963
# 5  5.0  55.0  57.2           56.85    5.173963
# 0    10cc55C
# Name: NOMBRE, dtype: object     tf    av   max  moving average  moving std
# 2  2.0  49.6  56.0           57.95    9.919577
# 3  3.0  52.5  56.3           57.95    9.919577
# 4  4.0  53.7  55.5           57.95    9.919577
# 5  5.0  55.3  56.5           57.95    9.919577
# 6  6.0  56.3  56.8           57.95    9.919577
# 0    10cc57C
# Name: NOMBRE, dtype: object     tf    av   max  moving average  moving std
# 1  1.0  42.3  55.1           58.25    3.414613
# 2  2.0  53.1  57.8           58.25    3.414613
# 3  3.0  57.8  58.3           58.25    3.414613
# 4  4.0  58.2  58.6           58.25    3.414613
# 5  5.0  58.5  59.0           58.25    3.414613
# 0    5cc55C
# Name: NOMBRE, dtype: object     tf    av   max  moving average  moving std
# 3  3.0  44.6  46.6            54.9    5.943406
# 4  4.0  48.5  49.6            54.9    5.943406
# 5  5.0  50.7  52.1            54.9    5.943406
# 6  6.0  53.6  54.6            54.9    5.943406
# 7  7.0  54.3  54.9            54.9    5.943406
# 0    5cc58C
# Name: NOMBRE, dtype: object       tf    av   max  moving average  moving std
# 3  3.033  51.5  56.2            59.1   12.535743
# 4  5.833  57.4  57.9            59.1   12.535743
# 5  6.833  58.1  58.7            59.1   12.535743
# 6  7.833  58.2  58.9            59.1   12.535743
# 7  8.833  58.2  59.0            59.1   12.535743
# 0    1cc48C
# Name: NOMBRE, dtype: object     tf    av   max  moving average  moving std
# 2  2.0  46.9  47.6           47.05    6.935348
# 3  3.0  45.7  46.7           47.05    6.935348
# 4  4.0  45.2  47.1           47.05    6.935348
# 5  5.0  45.7  47.0           47.05    6.935348
# 6  6.0  46.0  46.8           47.05    6.935348
# 0    1cc51C
# Name: NOMBRE, dtype: object     tf    av   max  moving average  moving std
# 2  2.0  30.1  31.5            46.6    7.706038
# 3  3.0  33.7  34.9            46.6    7.706038
# 4  4.0  36.0  37.5            46.6    7.706038
# 5  5.0  38.3  40.1            46.6    7.706038
# 6  6.0  39.0  41.2            46.6    7.706038

# %%
#se arman GRUPOS SEGUN CAUDAL
from itertools import groupby
count = 0

#key es la lista donde estan los diccionarios de exp y DF
#group es que se agrupa segun el valor de 'caudal' en este caso

for key, group in groupby(sorted(listatempcup, key=lambda x: x['caudal']), key=lambda x: x['caudal']):
    print(key)
    count += 1
    #for exp in group:
        #muestra el nombre del grupo y los elementos que tiene
        #print(exp['nombre'])
# Out:
# 1e-06
# 5e-06
# 1e-05
# 1.7e-05
# 2.5e-05

# %%
superlista = listatempcup + listatemp + listatemp4cup

# %%
for x in listatemp4cup:
    print(x['nombre'])
# Out:
# 5cc48C

# %%
#GENERA PATCHES DE COLORES SEGUN TEMPERATURA
import matplotlib.patches as mpatches

pat1 = mpatches.Patch(color='C1', label='temp < 40')
pat2 = mpatches.Patch(color='C2', label='temp < 45')
pat3 = mpatches.Patch(color='C3', label='temp < 50')
pat4 = mpatches.Patch(color='C4', label='temp < 55')
pat5 = mpatches.Patch(color='C5', label='temp < 60')
pat6 = mpatches.Patch(color='C6', label='temp < 65')
pat7 = mpatches.Patch(color='C7', label='temp < 70')


numerocolores = 7
colors = ['pat{}'.format(i+1) for i in range(numerocolores)]

print(colors)
# Out:
# ['pat1', 'pat2', 'pat3', 'pat4', 'pat5', 'pat6', 'pat7']

# %%
#5 graficos para temp NORMALIZADOS y AGRUPADOS POR CAUDAL para los 33 experimentos
fig = plt.figure()
axes = [fig.add_subplot(3,2,i+1) for i in range(5)]
counter = 0

for key, group in groupby(sorted(superlista, key=lambda x: x['caudal']), 
                          key=lambda x: x['caudal']):
    ax = axes[counter]
    ax.set_title('Caudal de {}cc'.format(key*1000000))
    print(key)
    counter += 1
    
    for i, exp in enumerate(group):
        tamb = exp['tamb']
        tmax = exp['av'].max()
        ax.plot(exp['tf']/exp['t*'], exp['av']/tamb)
        ax.set_ylabel('Temp (t)/ Temp amb')
        ax.set_xlabel('Tiempo / t*')
        print(exp['nombre'])
        ax.axvline(1, linestyle=':', color='black')
        ax.axhline(1, linestyle=':', color='black')



#plt.legend(handles=[linea1, linea2], title='Leyenda', bbox_to_anchor=(2.5, 0.2, 0.4, 0.4), 
           #loc=4, ncol=4)
    
plt.suptitle('Resumen de temperatura media superficial en el punto de eyección normalizada por temperatura ambiente')

legend1 = plt.legend(handles=[pat1, pat2, pat3, pat4, pat5, pat6, pat7], title='Temperatura inicial exp', bbox_to_anchor=(1.8, 0.5), loc=5)
#plt.legend(bbox_to_anchor=(1.8, 0.5), loc=6)
#plt.gca().add_artist(legend1)
fig.show()
# Out:
# 1e-06
# 1cc47C
# 1cc55C
# 1cc59C
# 1cc48C
# 1cc51C
# 1cc54,7C
# 1cc52C
# 5e-06
# 5cc59C
# 5cc53C
# 5cc57C
# 5cc55C
# 5cc58C
# 5cc48C
# 1e-05
# 10cc67C
# 10cc59C
# 10cc49C
# 10cc55C
# 10cc57C
# 10cc50C
# 1.7e-05
# 5a25cc56C
# 2.5e-05
# 25cc58C
# 25cc70C
# 25cc50C

# %%
#9 graficos para tempcup de temperatura av vs temperatura cup (superficial vs interior)
#intento de dibujo con arrows a tiempo fin de eyeccion
figu = plt.figure()
axes = [figu.add_subplot(4,3,i+1) for i in range(len(listatempcup))]
counter = 0

for exp in listatempcup:
        ax = axes[counter]
        counter += 1
        ax.set_title(exp['nombre'])
        #ax.set_xlim(-100, 2700)
        #ax.set_ylim(20, 72)
        tamb = exp['tamb']
        ax.plot(exp['tf'], exp['av']/tamb, 'r--', label='temp superficie')
        ax.plot(exp['tc'], exp['cp']/tamb, 'b-', label='temp termocupla')
        ax.set_ylabel('Temp medición/ambiente')
        ax.set_xlabel('Tiempo/Tiempo*')
        #ax.axvline(1, linestyle=':', color='g')
        #ax.axhline(1, linestyle=':', color='y')
        ax.annotate('tiempo fin eyección', xy=(exp['teyec'],2), xytext=(1000, 2), xycoords='data',
            arrowprops=dict(facecolor='black', shrink=0.001, width=0.1, headwidth=5))


        #ax.axvline(exp['t*'], linestyle=':', color='g')

linea1 = mlines.Line2D([],[], label='temp superficie', linestyle='--', color='r')
linea2 = mlines.Line2D([],[], label='temp termocupla', linestyle='-', color='b')
#linea3 = mlines.Line2D([],[], label='1', linestyle=':', color='g')
#linea4 = mlines.Line2D([],[], label='1', linestyle=':', color='y'), linea3, linea4

plt.legend(handles=[linea1, linea2], title='Leyenda', bbox_to_anchor=(2.5, 0.2, 0.4, 0.4), 
           loc=4, ncol=4)
plt.suptitle('Evolución temporal de temperatura superficial e interior del flujo en el punto de eyección para distintos caudales y temperaturas iniciales')
#labelLines(plt.gca().get_lines(), xvals=np.linspace(0, 0.23, c+2)[1: -1])
figu.show()

# %%
#5 graficos para temp
fig = plt.figure()
axes = [fig.add_subplot(3,2,i+1) for i in range(count)]
counter = 0

for key, group in groupby(sorted(listatemp, key=lambda x: x['caudal']), 
                          key=lambda x: x['caudal']):
    ax = axes[counter]
    ax.set_title('{}cc'.format(key*1000000))
    print(key)
    counter += 1

    for i, exp in enumerate(group):
        tamb = exp['tamb']
        ax.scatter(exp['tf']/exp['t*'], exp['max']/tamb)
        
#legend1 = plt.legend(handles=[pat1, pat2, pat3, pat4, pat5, pat6, pat7], bbox_to_anchor=(1.8, 0.5), loc=5)
#plt.legend(bbox_to_anchor=(1.8, 0.5), loc=6)
#plt.gca().add_artist(legend1)
fig.show()
# Out:
# 1e-06
# 5e-06
# 1e-05

# %%
#4 graficos para los 4 temp4cup
fig = plt.figure()
axes = [fig.add_subplot(2,2,i+1) for i in range(4)]
counter = 0

for exp in listatemp4cup:
    ax = axes[counter]
    #ax.set_title(exp['nombre'])
    #print(key)
    counter += 1
    ax.set_xlim(-100, 6500)
    ax.set_ylim(20, 58)
    #tamb = exp['tamb']
    ax.plot(exp['tf'], exp['av'], linestyle='--', color='c')
    ax.plot(exp['frame'], exp['frente'], linestyle='-.', color='g')
        
#legend1 = plt.legend(handles=[pat1, pat2, pat3, pat4, pat5, pat6, pat7], bbox_to_anchor=(1.8, 0.5), loc=5)
#plt.legend(bbox_to_anchor=(1.8, 0.5), loc=6)
#plt.gca().add_artist(legend1)
fig.show()

# %%
df[df['star field'] == df['star field'].min()]

# %%
#4 graficos para 1 temp4cup
fig = plt.figure()
axes = [fig.add_subplot(3,2,i+1) for i in range(6)]
counter = 0

exp = listatemp4cup[1]

#ax.set_xlim(-100, 2700)
#ax.set_ylim(20, 72)

ax = axes[0]
ax.plot(exp['tiempo'], exp['avance'], linestyle='-', color='c')
ax.plot(exp['tiempo'], exp['ancho'], linestyle='-.', color='crimson')
ax.set_xlim(-50, 4500)
ax.set_ylim(-0.1, exp['avance'].max()+0.1)
ax.set_ylabel('Distancia [m]')
ax.set_xlabel('Tiempo [s]')

ax = axes[1]
ax.plot(exp['teyec'] , df[df[largo] == largo*], 'o')
ax.annotate('annotate', xy=(2, 1), xytext=(3, 4),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.plot(exp['frame'], exp['frente'], linestyle='-.', color='m')
ax.set_xlim(-50,  4500)
ax.set_ylim(exp['tamb'], exp['av'].max()+3)
ax.set_xlabel('Tiempo [s] medición frente de flujo')
ax.set_ylabel('Temperatura [°C]')

ax = axes[2]
ax.plot(exp['tf'], exp['av'], linestyle=':', label='temperatura superficial', color='g')
ax.plot(exp['tf'], exp['cp1'], linestyle='--', label='termocupla', color='y')
ax.set_xlim(-50,  4500)
ax.set_ylim(exp['tamb'], exp['av'].max()+3)
ax.set_xlabel('Tiempo [s] medición Spot #1')
ax.set_ylabel('Temperatura [°C]')

ax = axes[3]
ax.plot(exp['tf'], exp['sp2'], linestyle=':', label='', color='g')
ax.plot(exp['tf'], exp['cp3'], linestyle='--', label='', color='y')
ax.set_xlim(-50,  4500)
ax.set_ylim(exp['tamb'], exp['av'].max()+3)
ax.set_xlabel('Tiempo [s] medición Spot #2')
ax.set_ylabel('Temperatura [°C]')

ax = axes[4]
ax.plot(exp['tf'], exp['sp3'], linestyle=':', label='', color='g')
ax.plot(exp['tf'], exp['cp3'], linestyle='--', label='', color='y')
ax.set_xlim(-50,  4500)
ax.set_ylim(exp['tamb'], exp['av'].max()+3)
ax.set_xlabel('Tiempo [s] medición Spot #3')
ax.set_ylabel('Temperatura [°C]')

ax = axes[5]
ax.plot(exp['tf'], exp['sp4'], linestyle=':', label='', color='g')
ax.plot(exp['tf'], exp['cp4'], linestyle='--', label='', color='y')
ax.set_xlim(-50,  4500)
ax.set_ylim(exp['tamb'], exp['av'].max()+3)
ax.set_xlabel('Tiempo [s] medición Spot #4')
ax.set_ylabel('Temperatura [°C]')

tempsup = mlines.Line2D([], [], color='g', linestyle=':', marker='',markersize=15, label='Temp. superficial')
tempcup = mlines.Line2D([], [], color='y', linestyle='--', marker='',markersize=15, label='Temp. termocupla')
avance = mlines.Line2D([], [], color='c', linestyle='-', marker='',markersize=15, label='Avance del frente flujo')
ancho = mlines.Line2D([], [], color='crimson', linestyle='-.', marker='',markersize=15, label='Avance del ancho flujo')
frente = mlines.Line2D([], [], color='m', linestyle='-', marker='',markersize=15, label='Temp. frente de flujo')

plt.legend(handles=[tempsup, tempcup, avance, frente, ancho], title='Leyenda', loc=0, bbox_to_anchor=(0.0, 4, 1., .102),
           ncol=4)
plt.suptitle('Evolución temporal experimento #30 {}[m3/s]'.format(exp['caudal']), fontsize=14, fontweight='bold')
plt.show()
exp['nombre']
#mode="expand", , borderaxespad=0.
# Out:
# '10cc50C'

# %%
#4 graficos para 1 temp4cup
fig = plt.figure()
axes = [fig.add_subplot(5,1,i+1) for i in range(5)]
counter = 0

exp = listatemp4cup[1]

#ax.set_xlim(-100, 2700)
#ax.set_ylim(20, 72)

ax = axes[0]
ax.plot(exp['tiempo'], exp['avance'], linestyle='-', color='c')
ax.plot(exp['tiempo'], exp['ancho'], linestyle='-.', color='crimson')
#ax.set_xlim(-50, 4500)
#ax.set_ylim(-0.1, exp['avance'].max()+0.1)
ax.set_ylabel('Distancia [m]')
ax.set_xlabel('Tiempo [s]')

ax = axes[1]
ax.plot(exp['frame'], exp['frente'], linestyle='-.', color='m')
#ax.set_xlim(-50,  4500)
#ax.set_ylim(exp['tamb'], exp['av'].max()+3)
ax.set_xlabel('Tiempo [s] medición frente de flujo')
ax.set_ylabel('Temperatura [°C]')

ax = axes[2]
ax.plot(exp['tf'], exp['av'], linestyle=':', label='temperatura superficial', color='g')
ax.plot(exp['tf'], exp['cp1'], linestyle='--', label='termocupla', color='y')
#ax.set_xlim(-50,  4500)
#ax.set_ylim(exp['tamb'], exp['av'].max()+3)
ax.set_xlabel('Tiempo [s] medición Spot #1')
ax.set_ylabel('Temperatura [°C]')

ax = axes[3]
ax.plot(exp['tf'], exp['sp2'], linestyle=':', label='', color='g')
ax.plot(exp['tf'], exp['cp3'], linestyle='--', label='', color='y')
#ax.set_xlim(-50,  4500)
#ax.set_ylim(exp['tamb'], exp['av'].max()+3)
ax.set_xlabel('Tiempo [s] medición Spot #2')
ax.set_ylabel('Temperatura [°C]')

ax = axes[4]
ax.plot(exp['tf'], exp['sp3'], linestyle=':', label='', color='g')
ax.plot(exp['tf'], exp['cp3'], linestyle='--', label='', color='y')
#ax.set_xlim(-50,  4500)
#ax.set_ylim(exp['tamb'], exp['av'].max()+3)
ax.set_xlabel('Tiempo [s] medición Spot #3')
ax.set_ylabel('Temperatura [°C]')

tempsup = mlines.Line2D([], [], color='g', linestyle=':', marker='',markersize=15, label='Termperatura superficial')
tempcup = mlines.Line2D([], [], color='y', linestyle='--', marker='',markersize=15, label='Termperatura termocupla')
avance = mlines.Line2D([], [], color='c', linestyle='-.', marker='',markersize=15, label='Avance del flujo')
frente = mlines.Line2D([], [], color='m', linestyle='-', marker='',markersize=15, label='Temperatura frente de flujo')
ancho = mlines.Line2D([], [], color='crimson', linestyle='-.', marker='',markersize=15, label='Avance del ancho flujo')

plt.legend(handles=[tempsup, tempcup, avance, frente, ancho], title='Leyenda', bbox_to_anchor=(0., 7, 1., .102), loc=1, 
           ncol=4, mode="expand", borderaxespad=0.)

plt.show()
plt.suptitle('Evolución temporal experimento #30 5[cc/s]')
plt.show()
exp['nombre']
# Out:
# '10cc50C'

# %%
#4 graficos para 1 temp4cup
fig = plt.figure()
axes = [fig.add_subplot(5,1,i+1) for i in range(5)]
counter = 0

exp = listatemp4cup[3]

#ax.set_xlim(-100, 2700)
#ax.set_ylim(20, 72)

ax = axes[0]
ax.plot(exp['tiempo'], exp['avance'], linestyle='-', color='c')
#ax.set_xlim(-50, 4500)
#ax.set_ylim(-0.1, exp['avance'].max()+0.1)

ax = axes[1]
ax.plot(exp['frame'], exp['frente'], linestyle='-.', color='m')
#ax.set_xlim(-50,  4500)
#ax.set_ylim(exp['tamb'], exp['sp1'].max()+3)

ax = axes[2]
ax.plot(exp['tf'], exp['sp1'], linestyle=':', label='temperatura superficial', color='g')
ax.plot(exp['tf'], exp['cp1'], linestyle='--', label='termocupla', color='y')
#ax.set_xlim(-50,  4500)
#ax.set_ylim(exp['tamb'], exp['sp1'].max()+3)

ax = axes[3]
ax.plot(exp['tf'], exp['sp2'], linestyle=':', label='', color='g')
ax.plot(exp['tf'], exp['cp3'], linestyle='--', label='', color='y')
#ax.set_xlim(-50,  4500)
#ax.set_ylim(exp['tamb'], exp['sp1'].max()+3)

ax = axes[4]
ax.plot(exp['tf'], exp['sp3'], linestyle=':', label='', color='g')
ax.plot(exp['tf'], exp['cp3'], linestyle='--', label='', color='y')
#ax.set_xlim(-50,  4500)
#ax.set_ylim(exp['tamb'], exp['sp1'].max()+3)

tempsup = mlines.Line2D([], [], color='g', linestyle=':', marker='',markersize=15, label='Termperatura superficial')
tempcup = mlines.Line2D([], [], color='y', linestyle='--', marker='',markersize=15, label='Termperatura termocupla')
avance = mlines.Line2D([], [], color='c', linestyle='-.', marker='',markersize=15, label='Avance del flujo')
frente = mlines.Line2D([], [], color='m', linestyle='-', marker='',markersize=15, label='Temperatura frente de flujo')

plt.legend(handles=[tempsup, tempcup, avance, frente], bbox_to_anchor=(0., 7, 1., .102), loc=1, 
           ncol=4, mode="expand", borderaxespad=0.)

plt.show()
exp['nombre']
# Out:
# '1cc52C'

# %%
plt.subplot(211)
plt.plot([1,2,3], label="test1")
plt.plot([3,2,1], label="test2")
# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)

plt.subplot(223)
plt.plot([1,2,3], label="test1")
plt.plot([3,2,1], label="test2")
# Place a legend to the right of this smaller subplot.
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.show()
